# %%
# !unzip '/content/Infant Mortality Dataset.zip' -d /content/
# Out:
# Archive:  /content/Infant Mortality Dataset.zip
# replace /content/1. youth-mortality-rate.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# General Overview
# Child and infant mortality rates remain a critical issue in Africa, impeding progress toward several
# Sustainable Development Goals (SDGs), including Goal 3: Good Health and Well-being. By leveraging
# data-driven approaches, this hackathon aims to identify actionable insights, develop innovative
# solutions, and contribute to global efforts to reduce preventable deaths in children under five years
# of age.
# Objective
# The primary objective is to utilize the provided datasets to uncover patterns, correlations, and key
# drivers of child and infant mortality in African countries. Participants will propose data-driven
# strategies and interventions that policymakers, healthcare providers, and organizations can adopt
# to improve health outcomes for children.
# Expected Outcomes
# Participants are expected to:
# 1. Build visualizations that highlight trends in child and infant mortality rates.
# 2. Identify socioeconomic, healthcare, and environmental factors contributing to high mortality
# rates.
# 3. Propose actionable recommendations to address gaps in vaccination coverage, healthcare
# access, and maternal support.
# 4. Develop predictive models to identify regions and populations at higher risk.
# 5. Present insights in a format that is accessible to policymakers and stakeholders
# We encourage participants to approach this case study with creativity, analytical rigor, and a focus
# on practical, implementable solutions. The insights derived from this analysis have the potential to
# inform policy, shape educational and economic strategies, and ultimately contribute to the
# reduction of child and infant mortality in Africa.

# %%
#for question 1, which is to highlight
'''trends in child and infant mortality rates,I'll use data sets
 4 to 7 to plot line charts showing the trend of mortality rates ovet ime'''
# Out:
# "trends in child and infant mortality rates,I'll use data sets\n 4 to 7 to plot line charts showing the trend of mortality rates ovet ime"

# %% [markdown]
# Data Dictionary for D1
#
# 7. Youth Mortality Rate
#
# Fields Description
# Entity Name of the country or region.
# Code Country code (ISO 3-letter format).
# Year Year of observation.
# Under-fifteen mortality rate Number of deaths per 1,000 live births for children under 15

# %%
#investigate for trends in youth mortality rate
#load dataset
#plot line chart to show trends

# %%
#import necessary libraties
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
african_capitals = {
    'Algeria': 'Algiers',
    'Angola': 'Luanda',
    'Benin': 'Porto-Novo',
    'Botswana': 'Gaborone',
    'Burkina Faso': 'Ouagadougou',
    'Burundi': 'Gitega',
    'Cabo Verde': 'Praia',
    'Cameroon': 'Yaounde',
    'Central African Republic': 'Bangui',
    'Chad': 'N\'Djamena',
    'Comoros': 'Moroni',
    'Congo, Democratic Republic of the': 'Kinshasa',
    'Congo, Republic of the': 'Brazzaville',
    'Cote d\'Ivoire': 'Yamoussoukro',
    'Djibouti': 'Djibouti',
    'Egypt': 'Cairo',
    'Equatorial Guinea': 'Malabo',
    'Eritrea': 'Asmara',
    'Eswatini': 'Mbabane',
    'Ethiopia': 'Addis Ababa',
    'Gabon': 'Libreville',
    'Gambia': 'Banjul',
    'Ghana': 'Accra',
    'Guinea': 'Conakry',
    'Guinea-Bissau': 'Bissau',
    'Kenya': 'Nairobi',
    'Lesotho': 'Maseru',
    'Liberia': 'Monrovia',
    'Libya': 'Tripoli',
    'Madagascar': 'Antananarivo',
    'Malawi': 'Lilongwe',
    'Mali': 'Bamako',
    'Mauritania': 'Nouakchott',
    'Mauritius': 'Port Louis',
    'Morocco': 'Rabat',
    'Mozambique': 'Maputo',
    'Namibia': 'Windhoek',
    'Niger': 'Niamey',
    'Nigeria': 'Abuja',
    'Rwanda': 'Kigali',
    'Sao Tome and Principe': 'Sao Tome',
    'Senegal': 'Dakar',
    'Seychelles': 'Victoria',
    'Sierra Leone': 'Freetown',
    'Somalia': 'Mogadishu',
    'South Africa': 'Pretoria',
    'South Sudan': 'Juba',
    'Sudan': 'Khartoum',
    'Tanzania': 'Dodoma',
    'Togo': 'Lome',
    'Tunisia': 'Tunis',
    'Uganda': 'Kampala',
    'Zambia': 'Lusaka',
    'Zimbabwe': 'Harare'
}

# %%
#load dataset
youth_mortality_rate = pd.read_csv('/content/1. youth-mortality-rate.csv')
youth_mortality_rate.head()
# Out:
#         Entity Code  Year  Under-fifteen mortality rate
# 0  Afghanistan  AFG  1977                     30.110573
# 1  Afghanistan  AFG  1978                     29.290777
# 2  Afghanistan  AFG  1979                     28.479010
# 3  Afghanistan  AFG  1980                     27.649078
# 4  Afghanistan  AFG  1981                     26.834482

# %%
# Filter for rows where the 'Entity' value is in the keys of 'african_capitals'
youth_mortality_rate = youth_mortality_rate[youth_mortality_rate['Entity'].isin(african_capitals.keys()) | youth_mortality_rate['Entity'].isin(african_capitals.values())]
youth_mortality_rate.head()
# Out:
#       Entity Code  Year  Under-fifteen mortality rate
# 112  Algeria  DZA  1979                     18.178753
# 113  Algeria  DZA  1980                     16.790104
# 114  Algeria  DZA  1981                     15.191734
# 115  Algeria  DZA  1982                     13.394593
# 116  Algeria  DZA  1983                     11.594862

# %%
# @title Under-fifteen mortality rate

from matplotlib import pyplot as plt
youth_mortality_rate['Under-fifteen mortality rate'].plot(kind='hist', bins=25, title='Under-fifteen mortality rate')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Year

from matplotlib import pyplot as plt
youth_mortality_rate['Year'].plot(kind='hist', bins=20, title='Year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Year vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['Year']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'Year'}, axis=1)
              .sort_values('Year', ascending=True))
  xs = counted['Year']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = youth_mortality_rate.sort_values('Year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
_ = plt.ylabel('count()')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

def plot_series_with_minmaxavg(df, series_name):
  palette = list(sns.palettes.mpl_palette('Dark2'))

  # Calculate min, max, and average for each year
  agg_data = df.groupby('Year')['Under-fifteen mortality rate'].agg(['min', 'max', 'mean'])
  agg_data = agg_data.reset_index()  # Reset index for plotting

  # Plot the lines
  plt.plot(agg_data['Year'], agg_data['mean'], label=f'{series_name} (Average)', color=palette[0])
  plt.plot(agg_data['Year'], agg_data['min'], label=f'{series_name} (Minimum)', color=palette[1], linestyle='--')
  plt.plot(agg_data['Year'], agg_data['max'], label=f'{series_name} (Maximum)', color=palette[2], linestyle='--')

# Assuming your DataFrame is named 'youth_mortality_rate'
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = youth_mortality_rate.sort_values('Year', ascending=True)

plot_series_with_minmaxavg(df_sorted, 'Youth Mortality Rate')

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Mortality Rate')
plt.title('Youth Mortality Rate with Min, Max, and Average')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

def plot_maximum_bar_chart(df, series_name):
  palette = list(sns.palettes.mpl_palette('Dark2'))

  # Calculate maximum for each year
  max_data = df.groupby('Year')['Under-fifteen mortality rate'].max().reset_index()

  # Plot the bars
  plt.bar(max_data['Year'], max_data['Under-fifteen mortality rate'], color=palette[0], label=f'{series_name} (Maximum)')

  # Set x-axis ticks and labels
  plt.xticks(max_data['Year'], rotation=45, ha='right')  # Rotate labels for better readability

# Assuming your DataFrame is named 'youth_mortality_rate'
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = youth_mortality_rate.sort_values('Year', ascending=True)

plot_maximum_bar_chart(df_sorted, 'Youth Mortality Rate')

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Mortality Rate')
plt.title('Maximum Youth Mortality Rate by Year')
plt.legend()
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()
# Out:
# <ipython-input-72-0fc7b6b22815>:28: UserWarning:
#
# The figure layout has changed to tight

# %%
youth_mortality_rate.Year.value_counts()
# Out:
# Year
# 2014    51
# 2010    51
# 2002    51
# 2003    51
# 2004    51
#         ..
# 1956     2
# 1957     2
# 1953     1
# 1955     1
# 1954     1
# Name: count, Length: 70, dtype: int64

# %%
youth_mortality_rate['Entity'].value_counts()
# Out:
# Entity
# Guinea                      70
# Mauritius                   67
# Seychelles                  65
# Togo                        63
# Lesotho                     57
# Kenya                       57
# Cameroon                    56
# Senegal                     56
# Madagascar                  55
# Tunisia                     55
# Burundi                     55
# Sudan                       55
# Morocco                     54
# Egypt                       54
# Cote d'Ivoire               54
# Mauritania                  53
# Benin                       52
# Rwanda                      51
# Liberia                     48
# Mali                        47
# Ghana                       46
# Uganda                      46
# Zimbabwe                    46
# Nigeria                     44
# Algeria                     44
# Tanzania                    43
# Botswana                    43
# Namibia                     42
# Niger                       42
# Malawi                      42
# ...

# %%
youth_mortality_rate.groupby('Entity')['Under-fifteen mortality rate'].sum()
# Out:
# Entity
# Algeria                      252.741655
# Angola                       591.349627
# Benin                        980.308284
# Botswana                     310.879427
# Burkina Faso                 746.002953
# Burundi                     1078.015947
# Cameroon                     951.525632
# Central African Republic     691.777259
# Chad                         728.591416
# Comoros                      382.039904
# Cote d'Ivoire                905.089532
# Djibouti                     337.892799
# Egypt                        547.820314
# Equatorial Guinea            496.626090
# Eritrea                      431.978836
# Eswatini                     316.978219
# Ethiopia                     485.403737
# Gabon                        287.027214
# Gambia                       366.053832
# Ghana                        560.292360
# Guinea                      1932.985120
# Guinea-Bissau                538.503488
# Kenya                        614.216820
# ...

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each entity
entity_sum = youth_mortality_rate.groupby('Entity')['Under-fifteen mortality rate'].sum().reset_index()

# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')  # Adjust figsize as needed
plt.bar(entity_sum['Entity'], entity_sum['Under-fifteen mortality rate'])

sns.despine(fig=fig, ax=ax)
plt.xlabel('Entity')
plt.ylabel('Sum of Under-fifteen Mortality Rate')
plt.title('Sum of Under-fifteen Mortality Rate by Entity', loc='left')  # Title on the left
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)  # Add grids
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-76-3789c6a6a8c4>:15: UserWarning:
#
# The figure layout has changed to tight

# %%
youth_mortality_rate.groupby('Year')['Under-fifteen mortality rate'].sum()
# Out:
# Year
# 1953     44.452150
# 1954     44.181377
# 1955     43.905357
# 1956     59.158040
# 1957     56.847813
#            ...
# 2018    383.201504
# 2019    372.715918
# 2020    362.364710
# 2021    351.735310
# 2022    341.945353
# Name: Under-fifteen mortality rate, Length: 70, dtype: float64

# %%
import plotly.express as px

fig = px.choropleth(entity_sum, locations='Entity', locationmode='country names',
                    color='Under-fifteen mortality rate',
                    title='Sum of Under-fifteen Mortality Rate by Country',
                    color_continuous_scale='Viridis')
fig.update_layout(title_x=0)  # Shift title to the left
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each year
yearly_sum = youth_mortality_rate.groupby('Year')['Under-fifteen mortality rate'].sum().reset_index()

# Create the line chart
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
plt.plot(yearly_sum['Year'], yearly_sum['Under-fifteen mortality rate'], marker='o', linestyle='-')  # Added markers for data points

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Sum of Under-fifteen Mortality Rate')
plt.title('Trend of Under-fifteen Mortality Rate Over Time',loc = 'left')
plt.grid(True)  # Added grid for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-79-14a5c01ab729>:18: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# Data Dictionary for D2
#
# 6. Infant Deaths
#
# Fields Description
#
# Entity Name of the country or region.
#
# Code Country code (ISO 3-letter format).
#
# Year Year of observation.
#
# Deaths - Sex: all - Age: 0 Total number of infant deaths (age 0) for the given year.

# %%
infant_mortality_rate = pd.read_csv('/content/2. number-of-infant-deaths-unwpp.csv')
infant_mortality_rate.head()
# Out:
#         Entity Code  Year  Deaths - Sex: all - Age: 0 - Variant: estimates
# 0  Afghanistan  AFG  1950                                         109220.0
# 1  Afghanistan  AFG  1951                                         107971.0
# 2  Afghanistan  AFG  1952                                         108140.0
# 3  Afghanistan  AFG  1953                                         108248.0
# 4  Afghanistan  AFG  1954                                         108241.0

# %%
infant_mortality_rate.rename(columns={'Deaths - Sex: all - Age: 0 - Variant: estimates':'Deaths'},inplace = True)

# %%
# Filter for rows where the 'Entity' value is in the keys of 'african_capitals'
infant_mortality_rate = infant_mortality_rate[infant_mortality_rate['Entity'].isin(african_capitals.keys()) | infant_mortality_rate['Entity'].isin(african_capitals.values())]
infant_mortality_rate.head()
# Out:
#       Entity Code  Year   Deaths
# 222  Algeria  DZA  1950  74078.0
# 223  Algeria  DZA  1951  77950.0
# 224  Algeria  DZA  1952  78849.0
# 225  Algeria  DZA  1953  79839.0
# 226  Algeria  DZA  1954  81147.0

# %%
infant_mortality_rate.head()
# Out:
#       Entity Code  Year   Deaths
# 222  Algeria  DZA  1950  74078.0
# 223  Algeria  DZA  1951  77950.0
# 224  Algeria  DZA  1952  78849.0
# 225  Algeria  DZA  1953  79839.0
# 226  Algeria  DZA  1954  81147.0

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

def plot_series_with_minmaxavg(df, series_name):
  palette = list(sns.palettes.mpl_palette('Dark2'))

  # Calculate min, max, and average for each year
  agg_data = df.groupby('Year')['Deaths'].agg(['min', 'max', 'mean'])
  agg_data = agg_data.reset_index()  # Reset index for plotting

  # Plot the lines
  plt.plot(agg_data['Year'], agg_data['mean'], label=f'{series_name} (Average)', color=palette[0])
  plt.plot(agg_data['Year'], agg_data['min'], label=f'{series_name} (Minimum)', color=palette[1], linestyle='--')
  plt.plot(agg_data['Year'], agg_data['max'], label=f'{series_name} (Maximum)', color=palette[2], linestyle='--')

# Assuming your DataFrame is named 'youth_mortality_rate'
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = infant_mortality_rate.sort_values('Year', ascending=True)

plot_series_with_minmaxavg(df_sorted, 'Deaths')

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Mortality Rate')
plt.title('Infants Mortality Rate with Min, Max, and Average')
plt.legend()
plt.show()

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each year
yearly_sum = infant_mortality_rate.groupby('Year')['Deaths'].sum().reset_index()

# Create the line chart
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
plt.plot(yearly_sum['Year'], yearly_sum['Deaths'], marker='o', linestyle='-')  # Added markers for data points

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Sum of Infant Mortality Rate')
plt.title('Trend of Infant Mortality Rate Over Time',loc = 'left')
plt.grid(True)  # Added grid for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-85-62ec2209dec1>:14: UserWarning:
#
# The figure layout has changed to tight

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each entity
entity_sum = infant_mortality_rate.groupby('Entity')['Deaths'].sum().reset_index()

# Create the bar chart
fig, ax = plt.subplots(figsize=(15, 10), layout='constrained')  # Adjust figsize as needed
plt.bar(entity_sum['Entity'], entity_sum['Deaths'])

sns.despine(fig=fig, ax=ax)
plt.xlabel('Entity')
plt.ylabel('Sum of Under-fifteen Mortality Rate')
plt.title('Sum of Under-fifteen Mortality Rate by Entity', loc='left')  # Title on the left
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)  # Add grids
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-104-da10e870f528>:15: UserWarning:
#
# The figure layout has changed to tight

# %%
entity_sum.max()
# Out:
# Entity      Zimbabwe
# Deaths    34722522.0
# dtype: object

# %%
import plotly.express as px

fig = px.choropleth(entity_sum, locations='Entity', locationmode='country names',
                    color='Deaths',
                    title='Sum of Infant Mortality Rate by Country',
                    color_continuous_scale='Viridis')
fig.update_layout(title_x=0)  # Shift title to the left
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Data Dictionary for D3
#
# 5. Child Mortality by Income Level
#
# Fields Description
#
# Entity Name of the country or region.
#
# Code Country code (ISO 3-letter format).
#
# Year Year of observation.
#
# Under-five mortality rate Number of deaths of children under five

# %%
child_mortality_rate = pd.read_csv('/content/3. child-mortality-by-income-level-of-country.csv')

child_mortality_rate.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1957
# 1  Afghanistan  AFG  1958
# 2  Afghanistan  AFG  1959
# 3  Afghanistan  AFG  1960
# 4  Afghanistan  AFG  1961
#
#    Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births
# 0                                          37.245758
# 1                                          36.626625
# 2                                          36.043480
# 3                                          35.459850
# 4                                          34.894880

# %%
child_mortality_rate.rename(columns={'Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births':'Under-five mortality rate'},inplace = True)

# %%
# Filter for rows where the 'Entity' value is in the keys of 'african_capitals'
child_mortality_rate = child_mortality_rate[child_mortality_rate['Entity'].isin(african_capitals.keys()) | child_mortality_rate['Entity'].isin(african_capitals.values())]
child_mortality_rate.head()
# Out:
#       Entity Code  Year  Under-five mortality rate
# 202  Algeria  DZA  1954                  24.275417
# 203  Algeria  DZA  1955                  24.219950
# 204  Algeria  DZA  1956                  24.168736
# 205  Algeria  DZA  1957                  24.087566
# 206  Algeria  DZA  1958                  24.020243

# %%
def plot_series_with_minmaxavg(df, series_name):
  palette = list(sns.palettes.mpl_palette('Dark2'))

  # Calculate min, max, and average for each year
  agg_data = df.groupby('Year')['Under-five mortality rate'].agg(['min', 'max', 'mean'])
  agg_data = agg_data.reset_index()  # Reset index for plotting

  # Plot the lines
  plt.plot(agg_data['Year'], agg_data['mean'], label=f'{series_name} (Average)', color=palette[0])
  plt.plot(agg_data['Year'], agg_data['min'], label=f'{series_name} (Minimum)', color=palette[1], linestyle='--')
  plt.plot(agg_data['Year'], agg_data['max'], label=f'{series_name} (Maximum)', color=palette[2], linestyle='--')

# Assuming your DataFrame is named 'child_mortality_rate'
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = child_mortality_rate.sort_values('Year', ascending=True)

plot_series_with_minmaxavg(df_sorted, 'Deaths')

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Mortality Rate')
plt.title('Child Mortality Rate with Min, Max, and Average')
plt.legend()
plt.show()

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each year
yearly_sum = child_mortality_rate.groupby('Year')['Under-five mortality rate'].sum().reset_index()

# Create the line chart
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
plt.plot(yearly_sum['Year'], yearly_sum['Under-five mortality rate'], marker='o', linestyle='-')  # Added markers for data points

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Sum of Child Mortality Rate')
plt.title('Trend of child Mortality Rate Over Time',loc = 'left')
plt.grid(True)  # Added grid for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-93-4a2e2fcc8e1c>:14: UserWarning:
#
# The figure layout has changed to tight

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each entity
entity_sum = child_mortality_rate.groupby('Entity')['Under-five mortality rate'].sum().reset_index()

# Create the bar chart
fig, ax = plt.subplots(figsize=(15, 10), layout='constrained')  # Adjust figsize as needed
plt.bar(entity_sum['Entity'], entity_sum['Under-five mortality rate'])

sns.despine(fig=fig, ax=ax)
plt.xlabel('Entity')
plt.ylabel('Sum of child Mortality Rate')
plt.title('Sum of child Mortality Rate by Entity', loc='left')  # Title on the left
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)  # Add grids
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-94-c57785666a0b>:15: UserWarning:
#
# The figure layout has changed to tight

# %%
entity_sum.value_counts()
# Out:
# Entity                    Under-five mortality rate
# Algeria                   799.973285                   1
# Senegal                   1554.334506                  1
# Mali                      1416.048967                  1
# Mauritania                1414.497391                  1
# Mauritius                 294.183817                   1
# Morocco                   737.763050                   1
# Mozambique                1177.905850                  1
# Namibia                   417.511077                   1
# Niger                     1397.310162                  1
# Nigeria                   1163.317313                  1
# Rwanda                    1112.722851                  1
# Sao Tome and Principe     425.094021                   1
# Seychelles                412.442615                   1
# Madagascar                667.661153                   1
# Sierra Leone              1725.104848                  1
# Somalia                   664.182372                   1
# ...

# %%
import plotly.express as px

fig = px.choropleth(entity_sum, locations='Entity', locationmode='country names',
                    color='Under-five mortality rate',
                    title='Sum of Infant Mortality Rate by Country',
                    color_continuous_scale='Viridis')
fig.update_layout(title_x=0)  # Shift title to the left
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Data Dictionary for D5
#
# 4. Maternal Deaths by Region
#
# Fields Description
#
# Entity Name of the country or region.
#
# Code Country code (ISO 3-letter format).
#
# Year Year of observation.
#
# Estimated maternal deaths Estimated number of maternal deaths in the given year.

# %%
maternal_mortality_rate = pd.read_csv('/content/5. number-of-maternal-deaths-by-region.csv')
maternal_mortality_rate.head()
# Out:
#         Entity Code  Year  Estimated maternal deaths 959828-annotations
# 0  Afghanistan  AFG  1985                 10258.5340                NaN
# 1  Afghanistan  AFG  1986                  8671.9210                NaN
# 2  Afghanistan  AFG  1987                  8488.9600                NaN
# 3  Afghanistan  AFG  1988                  7522.1216                NaN
# 4  Afghanistan  AFG  1989                  7549.7050                NaN

# %%
# Filter for rows where the 'Entity' value is in the keys of 'african_capitals'
maternal_mortality_rate = maternal_mortality_rate[maternal_mortality_rate['Entity'].isin(african_capitals.keys()) | maternal_mortality_rate['Entity'].isin(african_capitals.values())]
maternal_mortality_rate.head()
# Out:
#       Entity Code  Year  Estimated maternal deaths 959828-annotations
# 108  Algeria  DZA  1985                  2187.8162                NaN
# 109  Algeria  DZA  1986                  2024.1606                NaN
# 110  Algeria  DZA  1987                  1966.3341                NaN
# 111  Algeria  DZA  1988                  1822.9799                NaN
# 112  Algeria  DZA  1989                  1744.9213                NaN

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each year
yearly_sum = maternal_mortality_rate.groupby('Year')['Estimated maternal deaths'].sum().reset_index()

# Create the line chart
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
plt.plot(yearly_sum['Year'], yearly_sum['Estimated maternal deaths'], marker='o', linestyle='-')  # Added markers for data points

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Sum of Maternal Mortality Rate')
plt.title('Trend of Maternal Mortality Rate Over Time',loc = 'left')
plt.grid(True)  # Added grid for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-99-0ec33bd6ea83>:14: UserWarning:
#
# The figure layout has changed to tight

# %%
# Assuming your DataFrame is named 'youth_mortality_rate'
# Calculate the sum of 'Under-fifteen mortality rate' for each entity
entity_sum = maternal_mortality_rate.groupby('Entity')['Estimated maternal deaths'].sum().reset_index()

# Create the bar chart
fig, ax = plt.subplots(figsize=(15, 10), layout='constrained')  # Adjust figsize as needed
plt.bar(entity_sum['Entity'], entity_sum['Estimated maternal deaths'])

sns.despine(fig=fig, ax=ax)
plt.xlabel('Entity')
plt.ylabel('Sum of maternal Mortality Rate')
plt.title('Sum of maternal Mortality Rate by Entity', loc='left')  # Title on the left
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)  # Add grids
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-100-ca543c346bf9>:15: UserWarning:
#
# The figure layout has changed to tight

# %%
def plot_series_with_minmaxavg(df, series_name):
  palette = list(sns.palettes.mpl_palette('Dark2'))

  # Calculate min, max, and average for each year
  agg_data = df.groupby('Year')['Estimated maternal deaths'].agg(['min', 'max', 'mean'])
  agg_data = agg_data.reset_index()  # Reset index for plotting

  # Plot the lines
  plt.plot(agg_data['Year'], agg_data['mean'], label=f'{series_name} (Average)', color=palette[0])
  plt.plot(agg_data['Year'], agg_data['min'], label=f'{series_name} (Minimum)', color=palette[1], linestyle='--')
  plt.plot(agg_data['Year'], agg_data['max'], label=f'{series_name} (Maximum)', color=palette[2], linestyle='--')

# Assuming your DataFrame is named 'youth_mortality_rate'
fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = maternal_mortality_rate.sort_values('Year', ascending=True)

plot_series_with_minmaxavg(df_sorted, 'Estimated maternal deaths')

sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
plt.ylabel('Mortality Rate')
plt.title('Maternal Mortality Rate with Min, Max, and Average')
plt.legend()
plt.show()

# %%
import plotly.express as px

fig = px.choropleth(entity_sum, locations='Entity', locationmode='country names',
                    color='Estimated maternal deaths',
                    title='Sum of Maternal Mortality Rate by Country',
                    color_continuous_scale='Viridis')
fig.update_layout(title_x=0)  # Shift title to the left
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
